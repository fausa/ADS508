# %%
import pandas as pd
import boto3
# !pip install s3fs
import s3fs
flights_df= pd.read_csv("s3://sagemaker-us-east-1-993410942383/content-project/airline_data/airline_flights_table/arline_flights_table.csv")
flights_df.head()
# Out:
# Requirement already satisfied: s3fs in c:\users\mohammad\anaconda3\lib\site-packages (2023.3.0)
# Requirement already satisfied: fsspec==2023.3.0 in c:\users\mohammad\anaconda3\lib\site-packages (from s3fs) (2023.3.0)
# Requirement already satisfied: aiobotocore~=2.4.2 in c:\users\mohammad\anaconda3\lib\site-packages (from s3fs) (2.4.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\mohammad\anaconda3\lib\site-packages (from s3fs) (3.8.1)
# Requirement already satisfied: botocore<1.27.60,>=1.27.59 in c:\users\mohammad\anaconda3\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (1.27.59)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\users\mohammad\anaconda3\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (0.11.0)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\mohammad\anaconda3\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (1.12.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mohammad\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (21.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\mohammad\anaconda3\lib\site-packages (from aioitertools>=0.5.1->aiobotocore~=2.4.2->s3fs) (4.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mohammad\anaconda3\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\mohammad\anaconda3\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (1.26.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\mohammad\anaconda3\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (0.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\mohammad\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\mohammad\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.2)
# C:\Users\Mohammad\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0           0  2016        1      1           6          3  2016-01-06
# 1           1  2016        1      1           7          4  2016-01-07
# 2           2  2016        1      1           8          5  2016-01-08
# 3           3  2016        1      1           9          6  2016-01-09
# 4           4  2016        1      1          10          7  2016-01-10
#
#   UniqueCarrier  AirlineID Carrier  ... Div1TotalGTime  Div1LongestGTime  \
# 0            AA      19805      AA  ...            NaN               NaN
# 1            AA      19805      AA  ...            NaN               NaN
# 2            AA      19805      AA  ...            NaN               NaN
# 3            AA      19805      AA  ...            NaN               NaN
# 4            AA      19805      AA  ...            NaN               NaN
#
#    Div1WheelsOff  Div1TailNum  Div2Airport Div2AirportID Div2AirportSeqID  \
# 0            NaN          NaN          NaN           NaN              NaN
# 1            NaN          NaN          NaN           NaN              NaN
# 2            NaN          NaN          NaN           NaN              NaN
# 3            NaN          NaN          NaN           NaN              NaN
# 4            NaN          NaN          NaN           NaN              NaN
#
#   Div2WheelsOn  Div2TotalGTime Div2LongestGTime
# 0          NaN             NaN              NaN
# 1          NaN             NaN              NaN
# 2          NaN             NaN              NaN
# 3          NaN             NaN              NaN
# 4          NaN             NaN              NaN
#
# [5 rows x 84 columns]

# %%
df_carrier = flights_df.groupby(["UniqueCarrier"]).Cancelled.sum().reset_index()
df_carrier = df_carrier.sort_values('Cancelled')

df_carrier
# Out:
#    UniqueCarrier  Cancelled
# 6             HA          4
# 5             F9         77
# 1             AS        139
# 10            VX        159
# 7             NK        308
# 2             B6        897
# 3             DL        974
# 8             OO        984
# 9             UA       1336
# 4             EV       1427
# 11            WN       2640
# 0             AA       2720

# %%
flights_df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'FlightDate', 'UniqueCarrier', 'AirlineID', 'Carrier', 'TailNum',
#        'FlightNum', 'OriginAirportID', 'OriginAirportSeqID',
#        'OriginCityMarketID', 'Origin', 'OriginCityName', 'OriginState',
#        'OriginStateFips', 'OriginStateName', 'OriginWac', 'DestAirportID',
#        'DestAirportSeqID', 'DestCityMarketID', 'Dest', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'CRSDepTime',
#        'DepTime', 'DepDelay', 'DepDelayMinutes', 'DepDel15',
#        'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut', 'WheelsOff',
#        'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay',
#        'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CRSElapsedTime',
#        'ActualElapsedTime', 'AirTime', 'Flights', 'Distance', 'DistanceGroup',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay', 'FirstDepTime', 'TotalAddGTime', 'LongestAddGTime',
#        'DivAirportLandings', 'DivReachedDest', 'DivActualElapsedTime',
#        'DivArrDelay', 'DivDistance', 'Div1Airport', 'Div1AirportID',
#        'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime',
#        'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum', 'Div2Airport',
#        'Div2AirportID', 'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime',
#        'Div2LongestGTime'],
#       dtype='object')

# %% [markdown]
# which airline had the most cancelled flights in 2016

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns




g_bar=sns.barplot(x="UniqueCarrier", y="Cancelled", data=df_carrier)
g_bar.set_title("Cancellations per Carriers")
# Out:
# Text(0.5, 1.0, 'Cancellations per Carriers')

# %% [markdown]
# Which days of month have the most delays?

# %%
df_dayofmonth = flights_df.groupby(["DayofMonth"]).Cancelled.sum().reset_index()

df_dayofmonth
# Out:
#     DayofMonth  Cancelled
# 0            1         57
# 1            2         52
# 2            3         97
# 3            4         87
# 4            5        204
# 5            6        235
# 6            7        173
# 7            8        187
# 8            9        145
# 9           10        167
# 10          11        112
# 11          12         96
# 12          13         84
# 13          14        100
# 14          15         38
# 15          16         77
# 16          17         78
# 17          18         72
# 18          19        134
# 19          20         87
# 20          21        126
# 21          22       2266
# 22          23       2868
# 23          24       2504
# 24          25        957
# 25          26        348
# 26          27         63
# 27          28         50
# 28          29         67
# 29          30         41
# 30          31         93

# %%
g_bar=sns.barplot(x="DayofMonth", y="Cancelled", data=df_dayofmonth)
g_bar.set_title("Cancellations per Day of Month")
# Out:
# Text(0.5, 1.0, 'Cancellations per Day of Month')

# %% [markdown]
# Which day of week has the most cancelled flights

# %%
df_DayOfWeek = flights_df.groupby(["DayOfWeek"]).Cancelled.sum().reset_index()
df_DayOfWeek
# Out:
#    DayOfWeek  Cancelled
# 0          1       1228
# 1          2        782
# 2          3        469
# 3          4        449
# 4          5       2615
# 5          6       3183
# 6          7       2939

# %%
g_bar=sns.barplot(x="DayOfWeek", y="Cancelled", data=df_DayOfWeek)
g_bar.set_title("Cancellations per Day Of Week")
# Out:
# Text(0.5, 1.0, 'Cancellations per Day Of Week')

# %%
weather_df= pd.read_csv("s3://sagemaker-us-east-1-993410942383/content-project/airline_data/WeatherUS_2016/WeatherUS_2016.csv")
weather_df.head()
# Out:
#    Unnamed: 0 EventId  Type Severity       StartTime(UTC)  \
# 0           0     W-1  Snow    Light  2016-01-06 23:14:00
# 1           1     W-2  Snow    Light  2016-01-07 04:14:00
# 2           2     W-3  Snow    Light  2016-01-07 05:54:00
# 3           3     W-4  Snow    Light  2016-01-08 05:34:00
# 4           4     W-5  Snow    Light  2016-01-08 13:54:00
#
#           EndTime(UTC)  Precipitation(in)     TimeZone AirportCode  \
# 0  2016-01-07 00:34:00               0.00  US/Mountain        K04V
# 1  2016-01-07 04:54:00               0.00  US/Mountain        K04V
# 2  2016-01-07 15:34:00               0.03  US/Mountain        K04V
# 3  2016-01-08 05:54:00               0.00  US/Mountain        K04V
# 4  2016-01-08 15:54:00               0.00  US/Mountain        K04V
#
#    LocationLat  LocationLng      City    County State  ZipCode
# 0      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 1      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 2      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 3      38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 4      38.0972    -106.1689  Saguache  Saguache    CO  81149.0

# %%
weather_df['StartTime(UTC)'] = pd.to_datetime(weather_df['StartTime(UTC)'])
weather_df['EndTime(UTC)'] = pd.to_datetime(weather_df['EndTime(UTC)'])
weather_df= weather_df.rename(columns={'Precipitation(in)': 'Precipitation_in'})

# %%
weather_df
# Out:
#          Unnamed: 0    EventId  Type  Severity      StartTime(UTC)  \
# 0                 0        W-1  Snow     Light 2016-01-06 23:14:00
# 1                 1        W-2  Snow     Light 2016-01-07 04:14:00
# 2                 2        W-3  Snow     Light 2016-01-07 05:54:00
# 3                 3        W-4  Snow     Light 2016-01-08 05:34:00
# 4                 4        W-5  Snow     Light 2016-01-08 13:54:00
# ...             ...        ...   ...       ...                 ...
# 1185986     7476860  W-7574893  Snow     Light 2016-12-25 18:00:00
# 1185987     7476861  W-7574894  Snow  Moderate 2016-12-25 18:30:00
# 1185988     7476862  W-7574895  Snow     Light 2016-12-25 20:16:00
# 1185989     7476863  W-7574896  Snow     Light 2016-12-31 07:53:00
# 1185990     7476864  W-7574897   Fog    Severe 2016-12-31 16:10:00
#
#                EndTime(UTC)  Precipitation_in     TimeZone AirportCode  \
# 0       2016-01-07 00:34:00              0.00  US/Mountain        K04V
# 1       2016-01-07 04:54:00              0.00  US/Mountain        K04V
# 2       2016-01-07 15:34:00              0.03  US/Mountain        K04V
# 3       2016-01-08 05:54:00              0.00  US/Mountain        K04V
# 4       2016-01-08 15:54:00              0.00  US/Mountain        K04V
# ...                     ...               ...          ...         ...
# 1185986 2016-12-25 18:30:00              0.01  US/Mountain        KBVR
# 1185987 2016-12-25 20:16:00              0.12  US/Mountain        KBVR
# 1185988 2016-12-26 00:53:00              0.16  US/Mountain        KBVR
# 1185989 2016-12-31 08:22:00              0.00  US/Mountain        KBVR
# 1185990 2016-12-31 16:24:00              0.00  US/Mountain        KBVR
#
#          LocationLat  LocationLng      City    County State  ZipCode
# 0            38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 1            38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 2            38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 3            38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# 4            38.0972    -106.1689  Saguache  Saguache    CO  81149.0
# ...              ...          ...       ...       ...   ...      ...
# 1185986      42.5833    -108.2833    Lander   Fremont    WY  82520.0
# 1185987      42.5833    -108.2833    Lander   Fremont    WY  82520.0
# 1185988      42.5833    -108.2833    Lander   Fremont    WY  82520.0
# 1185989      42.5833    -108.2833    Lander   Fremont    WY  82520.0
# 1185990      42.5833    -108.2833    Lander   Fremont    WY  82520.0
#
# [1185991 rows x 15 columns]

# %% [markdown]
# total precipitation for each city and state

# %%
weather_City=weather_df.groupby(["City"]).Precipitation_in.sum().reset_index()
weather_City
# Out:
#                          City  Precipitation_in
# 0                   Abbeville             86.53
# 1                    Aberdeen            163.58
# 2     Aberdeen Proving Ground              3.53
# 3                     Abilene             80.62
# 4                    Abingdon             75.54
# ...                       ...               ...
# 1711                     Yuma              2.92
# 1712               Zanesville             71.44
# 1713                   Zapata             39.29
# 1714              Zephyrhills             52.86
# 1715               Zionsville             58.57
#
# [1716 rows x 2 columns]

# %%
weather_state=weather_df.groupby(["State"]).Precipitation_in.sum().reset_index()
weather_state
# Out:
#    State  Precipitation_in
# 0     AL           3115.76
# 1     AR           9124.29
# 2     AZ           1118.57
# 3     CA           2821.14
# 4     CO           1003.03
# 5     CT            559.75
# 6     DE            247.00
# 7     FL           8750.89
# 8     GA           1803.96
# 9     IA           2887.96
# 10    ID            696.24
# 11    IL           5413.21
# 12    IN           4697.10
# 13    KS           2369.07
# 14    KY           1938.29
# 15    LA           5123.35
# 16    MA           1553.87
# 17    MD            778.11
# 18    ME           1905.60
# 19    MI           2822.61
# 20    MN           4507.48
# 21    MO           2732.93
# 22    MS           2176.95
# 23    MT           1839.23
# 24    NC           5103.70
# 25    ND           8930.92
# 26    NE           1838.51
# 27    NH           1152.22
# 28    NJ           2392.31
# 29    NM            816.23
# 30    NV            208.45
# 31    NY           7731.51
# 32    OH           2266.52
# 33    OK           2267.01
# 34    OR           1704.99
# 35    PA           2168.58
# 36    RI            292.85
# 37    SC           2607.19
# 38    SD            928.11
# 39    TN            989.93
# 40    TX          10172.16
# 41    UT            254.39
# 42    VA           3493.00
# 43    VT            375.18
# 44    WA           1709.85
# 45    WI           3309.76
# 46    WV           1045.65
# 47    WY           3317.93

# %%
plt.figure(figsize=(12,3))
sns.scatterplot(data=weather_state,x='State',y='Precipitation_in')
plt.xlabel('State')
plt.ylabel('Total Precipitation')
# Out:
# Text(0, 0.5, 'Total Precipitation')

# %%
import matplotlib.pyplot as plt

sns.countplot(data=flights_df, x="Year", hue="Cancelled")
plt.show()

# %%
df_grouped_by = flights_df.groupby(["Year","Cancelled"])["Year","Cancelled"]
df_balanced = df_grouped_by.apply(lambda x: x.sample(df_grouped_by.size().min()).reset_index(drop=True))
df_balanced.shape
# Out:
# C:\Users\Mohammad\AppData\Local\Temp/ipykernel_28140/4041968899.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped_by = flights_df.groupby(["Year","Cancelled"])["Year","Cancelled"]
# (23330, 2)

# %%
import seaborn as sns
sns.countplot(data=df_balanced, x="Cancelled")
# Out:
# <AxesSubplot:xlabel='Cancelled', ylabel='count'>
